# %% [markdown]
# # Графика в Python. Занятие 1

# %% [markdown]
# В данном курсе мы научимся применять свои умения в программировании и создам игру [Pong](https://en.wikipedia.org/wiki/Pong).

# %% [markdown]
# Наш курс начинается с первого занятия, в котором мы познакомимся со средой разработки программ (IDE) Thonny, библиотекой Tkinter, научимся создавать окно и поле для рисования, а также поймем, как рисовать простые объекты (линии, прямоугольники и другое).
#
# Приступим.

# %% [markdown]
# Для начала необходимо подключить библиотеку tkinter:

# %%
from tkinter import *

# %% [markdown]
# Нам надо где-то рисовать, для этого создадим окно. В нем укажем область, в которой и будем рисовать. Это окно имеет свои параметры, такие как размер, название и цвет. Создайте свое собственное поле для дальнейшего рисования:

# %%
Win1=Tk()
c = Canvas(Win1, width=800, height=500, bg='black')
c.pack()

# Ваш код должен быть расположен здесь.

Win1.mainloop()

# %% [markdown]
# Если вы запустили код, вы можете наблюдать "холст". На каждом холсте введена система координат - с её помощью можно задать каждому объекту место. Отсчет делается из левого верхнего угла (считаем, что там точка (0, 0)), вправо направлена ось X, а вниз ось Y. Сначала задаем точку по оси X, а потом - по оси Y.

# %% [markdown]
# Окно создали, давайте уже что-то нарисуем. В Tkinter есть несколько функций для рисования фигур и линий. из которых и составляются все изображения. У них в свою очередь очень много разных настроек от цвета, есть даже возможность рисовать пунктиром.

# %%
Win1=Tk()
c = Canvas(Win1, width=800, height=500, bg='black')
c.pack()

c.create_line(100, 180, 100, 60, fill='green', width=5, dash=(10,2))
c.create_rectangle(60, 80, 140, 190, fill='yellow', outline='green', width=3)
c.create_polygon(40, 110, 160, 110, 190, 180, 10, 180, fill='orange', outline='black')
c.create_oval(10, 120, 190, 190, fill='grey70', outline='white')

Win1.mainloop()

# %% [markdown]
# А теперь давайте нарисуем более сложные фигуры!
#
# **Задание:** нарисуйте домик с круглым окном и треугольной крышей.

# %% [markdown]
# Ну вот мы с рисованием и разобрались. Мы уже говорили,
# что в этом году мы будем как настоящие программисты писать уже более серьезные программы,
# и так же как и они, мы не будем делать это за 1 раз. Игру мы будем создавать на протяжении всего курса.
# И прямо сейчас создадим небольшую ее часть. Давайте нарисуем игровое поле, у нас оно будет черно-белым. Нарисуем мячики и ракетки на поле:

# %%
Win1=Tk()
c = Canvas(Win1, width=800, height=500, bg='black')
c.pack()

c.create_rectangle(45, 34, 755, 466, outline='white', width=8)
c.create_line(400, 50, 400, 450, fill='white', width=8, dash=(10,2))
c.create_rectangle(400, 300, 410, 310, fill='red')
c.create_line(61, 220, 61, 220+60, fill='white', width=8)
c.create_line(739, 220, 739, 220+60, fill='white', width=8)

Win1.mainloop()

# %% [markdown]
# Не забывайте, что мы делаем игру, а для этого нужно **хорошо разобраться** с пройденным материалом. Для этого необходимо выполнять задания, приведенные в каждом уроке.
#
# Каждое занятие в конце будет включать простые (отмечены буквой "A") и более сложные задачи ("B"). В каждой из категорий будет по 3 задачи, вам необходимо решить **все** из них.

# %% [markdown]
# Выполните следующие **задания:**
#
# A:
#
# 1. Давайте нарисуем елочку, используя треугольники и квадраты.
#
# 2. Теперь изобразим корону с помощью треугольников и кругов. Раскрасьте ее так, как захотите.
#
# 3. Создайте программу, которая нарисует три квадрата, расположенных друг за другом на некотором одинаковом расстоянии. Помните, что для упрощения повторяющихся действий мы используем цикл while.
#
# B:
#
# 1. Нарисуйте шахматную доску 8х8 клеток. Использование цикла while является обязательным.
#
# 2. Измените программу A3 так, чтобы она считывала число из окна ввода и рисовала столько квадратов, сколько ввел пользователь.
#
# 3. Сделайте так, чтобы каждый следующий квадрат был больше предыдущего (не забудьте правило о том, что квадраты должны находиться на одинаковом расстоянии друг от друга и не пересекаться).
#
# *Подсказка:* корона должна выглядеть примерно так:
#
# ![image.png](attachment:image.png)
