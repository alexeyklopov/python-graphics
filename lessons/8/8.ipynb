# %% [markdown]
# # Графика в Python. Занятие 8

# %% [markdown]
# *   Переход по пунктам меню
# *   Надпись Winner после партии

# %% [markdown]
# Вот мы с вами и вышли на финишную прямую. Наша игра почти готова, осталось только закончить меню и придумать какую-нибудь надпись для победителя.

# %% [markdown]
# Начнем с переходов по пунктам меню. Как, по-вашему, это можно реализовать?

# %% [markdown]
# На самом деле все очень просто. Мы создадим несколько функций, которые будут вызываться в зависимости от того, где мы находимся, в игровом меню, или непосредственно на игровом поле. Внутри каждой функции будет код того, что нужно отрисовывать. Давайте реализуем это. Но чтобы вы не просто переписывали код из урока себе в игру, с вами мы реализуем пример, а с игрой вы сделаете аналогичным образом.

# %% [markdown]
# Создайте новый проект. После чего добавьте на него холст 400 на 400. Создадим две функции. В одной будем рисовать треугольники в другой круги. Так же в каждой функции будет по кнопке, задача которой переключаться между треугольниками и кругами.

# %% [markdown]
# В одной функции пропишите заполнение всего поля треугольниками, как на картинке.

# %% [markdown]
# фото1

# %% [markdown]
# В центре создайте кнопку, на которой напишите “переход к кругам”. Создайте еще 1 функцию, которая будет срабатывать при нажатии на эту кнопку. Внутри нее при помощи изученных на прошлом уроке функций пропишем удаление виджета (т.е. кнопки) и рисунков с экрана, а так же вызов функции отрисовывающей круги.

# %%
def delet triangle():
    global button1
    c.delete("all")
    button1.destroy()
    oval()

# %% [markdown]
# Теперь повторите все с функцией, отвечающей за рисование кругов.

# %% [markdown]
# По такому же принципу будет работать переход по пунктам меню в нашей игре. Реализуйте это используя знания и умения, полученные на сегодняшнем уроке.

# %% [markdown]
# Осталось добавить надпись победителю. Тут все очень просто. Для начал придумайте при каком количестве очков игрок будет побеждать, например 7. Теперь надо в той функции, в игре, где у вас идет увеличение счетчика добавить проверку на то не достиг ли счетчик 7. Если достиг, то вызываем функцию, которая удаляет все с экрана и пишет посередине, какой игрок победил, после чего переходит в меню при помощи отложенного вызова функции.

# %% [markdown]
# # Задачи

# %% [markdown]
# 1.   Усовершенствуйте свою игру, добавив в нее настройки, в которых вы пользователь сможет изменять количество очков, которое надо набрать для победы.
#
#
# 2.   Добавьте возможность изменять скорость мячика.
